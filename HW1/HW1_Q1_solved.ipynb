# %% [markdown]
# # HW1 - Q1: Linear Algebra Basics (30 points)
# Notes:
# * Questions (a), (b), (c), and (d) need to be typewritten.
# * Important:
#   * Write all the steps of the solution.
#   * Use proper LATEX formatting and notation for all mathematical equations, vectors, and matrices.

# %% [markdown]
# ### **(a)** Given $L_1$ and $L_2$ are two lower triangular matrices of size $n\times n$, prove that $L_1L_2$ is also a lower triangular matrix. Further, prove by induction that multiplication of $m\,(m>2)$ lower triangular matrices ($L_1, L_2,..., L_m$) is also a lower triangular matrix. (6 points)

# %% [markdown]
# #### <font color="red">Your answer here:</font>
#
# Given: $\mathbf{L_1}$ and $\mathbf{L_2}$ are lower triangular matrices of size $n\times n$
#
# $$
# {\implies} \mathbf{(L_{1})_{ij}} = \begin{cases}
# 0,\ \forall \ i < j \\
# (L_{1})_{ij},\ \forall \ i \ge j \\
# \end{cases}
# \ \ , \ \
# \mathbf{(L_{2})_{ij}} = \begin{cases}
# 0,\ \forall \ i < j \\
# (L_{2})_{ij},\ \forall \ i \ge j \\
# \end{cases}
# $$
#
# Let $\mathbf{L} = \mathbf{L_1}\mathbf{L_2}$
#
# To prove that $\mathbf{L}$ is a lower triangular matrix, we need to show that $\mathbf{L_{ij}} = 0, \ \forall \ i < j$
#
# Fixing $i < j$, we have $\mathbf{L_{ij}} =$ ($i^{th}$ row of $\mathbf{L_{1}}$)$\cdot$($j^{th}$ column of $\mathbf{L_{2}}$)
#
# $$
# {\implies} \mathbf{L_{ij}} = \sum_{k=1}^{n}\mathbf{(L_{1})_{ik}}\mathbf{(L_{2})_{kj}}
# $$
# $$
# {\implies} \mathbf{L_{ij}} = \underbrace{\sum_{k=1}^{i}\mathbf{(L_{1})_{ik}}\mathbf{(L_{2})_{kj}}}_{0 \ \ (\because k \le i < j \ {\implies} \mathbf{(L_{2})_{kj}} = 0)} +
# \underbrace{\sum_{k=i+1}^{n}\mathbf{(L_{1})_{ik}}\mathbf{(L_{2})_{kj}}}_{0 \ \ (\because i < k \le j \ {\implies} \mathbf{(L_{1})_{ik}} = 0)}
# $$
# $$
# {\implies} \mathbf{L_{ij}} = 0 + 0 = 0
# $$
# Hence proved
#
# Also, to prove by induction $L_1 L_2...L_m$ is a lower triangular matrix for m>3, we have,
#
# For m=3, $L_1 L_2 L_3$ = $(L_1 L_2) L_3$ = $L_{12} L_3$ where $L_{12}$ is a lower triangular matrix as proved earlier that product of 2 lower triangular matrices is also a lower trianglular matrix.
#
# Hence, $L_1 L_2 L_3$ = $(L_{12} L_3)$ = $(L_{123})$ which will also be lower triangular.
#
# Assuming the condition also holds for m=k, we have $(L_{123...k})$ is a lower triangular matrix.
#
# For m = k + 1, $L_1 L_2...L_k L_{k+1}$ = $(L_1 L_2...L_k) L_{k+1}$ = $L_{12...k}L_{k+1}$ =$L_{12...k+1}$ which is also lower triangular.
#
# Hence proved.

# %% [markdown]
# ---

# %% [markdown]
# ### **(b)** Use Gauss elimination to solve the following equations: (8 points)
# $-4x_1 + 5x_2 - 5x_3 = -29$\
# $-8x_1  -5x_2 - 3x_3 = -15$\
# $16x_1 - 5x_2 + 6x_3 = 45$

# %% [markdown]
# #### <font color="red">Your answer here:</font>
# $\left[\begin{array}{ccc|c}
# -4 & 5 & -5 & -29 \\
# -8 & -5 & -3 & -15 \\
# 16 & -5 & 6 & 45
# \end{array}\right]
# {\begin{matrix}
#  \\
# R_2 \rightarrow R_2-2 R_{1}\\
# R_3 \rightarrow R_3 + 4R_1
# \end{matrix}}
# \left[\begin{array}{ccc|c}
# -4 & 5 & -5 & -29 \\
# 0 & -15 & 7 & -43 \\
# 0 & 15 & -14 & -71
# \end{array}\right]
# {\begin{matrix}
#  \\
#  \\
# R_3 \rightarrow R_3 + R_2
# \end{matrix}}
# \left[\begin{array}{ccc|c}
# -4 & 5 & -5 & -29 \\
# 0 & -15 & 7 & -43 \\
# 0 & 0 & -7 & -28
# \end{array}\right]$
#
# $\begin{cases}
# -4x_1 + 5x_2 - 5x_3 = -29 \\
# -15x_2 + 7x_3 = 43 \\
# -7x_3 = -28
# \end{cases}\rightarrow\begin{cases}
# x_1 = 1 \\
# x_2 = -1 \\
# x_3 = 4
# \end{cases}$

# %% [markdown]
# ---

# %% [markdown]
# ### **(c)** Do the $LU$ decomposition for the matrix obtained in (b). Using the matrices $L$ and $U$, do forward and backward substitution and solve for $\mathbf{x}$. Match your answer with the solution obtained in (b). (8 points)

# %% [markdown]
# #### <font color="red">Your answer here:</font>
#
# Let   $A = LU$
#
# $\left[\begin{matrix}
# -4 & 5 & -5 \\
# -8 & -5 & -3 \\
# 16 & -5 & 6
# \end{matrix}\right]
# {\begin{matrix}
#  \\
# R_2 \rightarrow -2 R_{1} + R_2 \\
# R_3 \rightarrow 4R_1 + R_3
# \end{matrix}}
# \left[\begin{matrix}
# -4 & 5 & -5 \\
# 0 & -15 & 7 \\
# 0 & 15 & -14
# \end{matrix}\right]
# {\begin{matrix}
#  \\
#  \\
# R_3 \rightarrow R_2 + R_3
# \end{matrix}}
# \left[\begin{matrix}
# -4 & 5 & -5  \\
# 0 & -15 & 7 \\
# 0 & 0 & -7
# \end{matrix}\right]$
#
# $ \rightarrow L = \begin{bmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# -4 & -1 & 1
# \end{bmatrix},
# U = \begin{bmatrix}
# 4 & 5 & -5 \\
# 0 & -15 & 7 \\
# 0 & 0 & 7
# \end{bmatrix}$
#
# Solve $AX = B \rightarrow $ Solve $ LUX = B$
#
# Let $ UX = Y$
#
# Step 1: First solve $ LY = B$ for $Y$
#
# $\begin{bmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# -4 & -1 & 1
# \end{bmatrix}
# \times \begin{bmatrix}
# y_1\\
# y_2 \\
# y_3
# \end{bmatrix} = \begin{bmatrix}
# -29\\
# -15 \\
# 45
# \end{bmatrix} \rightarrow \begin{cases}
# y_1 = -29 \\
# 2y_1 + y_2 = -15 \\
# -4y_1 - y_2 + y_3 = 45
# \end{cases}\rightarrow \begin{cases}
# y_1 = -29 \\
# y_2 = 43 \\
# y_3 = -28
# \end{cases}$
#
# Step 2: Then solve $ UX = Y$ for $X$
#
# $ \begin{bmatrix}
# 4 & 5 & -5 \\
# 0 & -15 & 7 \\
# 0 & 0 & 7
# \end{bmatrix} \times \begin{bmatrix}
# x_1\\
# x_2 \\
# x_3
# \end{bmatrix} = \begin{bmatrix}
# -29\\
# 43 \\
# -28
# \end{bmatrix} \rightarrow \begin{cases}
# -4x_1 + 5x_2 -5x_3 = -29 \\
# -15x_2 + 7 x_3 = 43 \\
# -7x_3 = -28
# \end{cases}\rightarrow \begin{cases}
# x_1 = 1 \\
# x_2 = -1 \\
# x_3 = 4
# \end{cases}$

# %% [markdown]
# ---

# %% [markdown]
# ### **(d)** Do the $QR$ decomposition for the matrix obtained in (b) using Gram-Schmidt algorithm. Using the decomposition, solve for $\mathbf{x}$. Match your answer with the solution obtained in problem (b). (8 points)

# %% [markdown]
# #### <font color="red">Your answer here:</font>
# Given : From part (b), we have $\mathbf A \mathbf{x} = \mathbf b$
# where $\mathbf A$ = $\mathbf{
#             {
#             \begin{bmatrix}
#                 \rm -4 & \rm 5 & \rm -5\\
#                 \rm -8 & \rm -5 & \rm -3\\
#                 \rm 16 & \rm -5 & \rm 6\\
#             \end{bmatrix}}}
#             $
# , $\mathbf{x}$ = $\mathbf{
#                 {
#                 \begin{bmatrix}
#                     \rm x_1 \\
#                     \rm x_2\\
#                     \rm x_3\\
#                 \end{bmatrix}}}
#                 $
# , $\mathbf b$ = = $\mathbf{
#                 {
#                 \begin{bmatrix}
#                     \rm -29 \\
#                     \rm -15\\
#                     \rm 45\\
#                 \end{bmatrix}}}
#                 $
#
# To Solve: $x_1, x_2, x_3$ using QR Factorization by the Gram-Schmidt Algorithm.
#
# Solution:
#
# Using the Gram-Schmidt Algorithm, we have :
# $\mathbf A$ =  $\mathbf{
#                 {
#                 \begin{bmatrix}
#                     | & | & | \\
#                     \mathbf {a_1} & \mathbf {a_2} & \mathbf {a_3} \\
#                     | & | & | \\
#                 \end{bmatrix}}}
#                 $
# , $\mathbf Q$ =  $\mathbf{
#                 {
#                 \begin{bmatrix}
#                     | & | & | \\
#                     \mathbf {q_1} & \mathbf {q_2} & \mathbf {q_3} \\
#                     | & | & | \\
#                 \end{bmatrix}}}
#                 $
#         = $\mathbf{
#                 {
#                 \begin{bmatrix}
#                     | & | & | \\
#                     \frac{\mathbf a_1}{||{\mathbf a_1}||} &  \frac{\mathbf a_2^{\perp}}{||{\mathbf a_2^{\perp}}||} & \frac{\mathbf a_3^{\perp}}{||{\mathbf a_3^{\perp}}||} \\
#                     | & | & | \\
#                 \end{bmatrix}}}
#                 $
#
# , $\mathbf R$ =  $\mathbf{
#                 {
#                 \begin{bmatrix}
#                     {r_{11}} & {r_{12}} & {r_{13}} \\
#                     0 & {r_{22}} & {r_{23}} \\
#                     0 & 0 & {r_{33}} \\
#                 \end{bmatrix}}}
#                 $
#         =  $\mathbf{
#                 {
#                 \begin{bmatrix}
#                     ||\mathbf {a_1}|| & {\mathbf a_2^{T}q_1}  & {\mathbf a_3^{T}q_1} \\
#                     0 & ||{\mathbf a_2}^{\perp}|| & {\mathbf a_3^{T}q_2} \\
#                     0 & 0 & ||{\mathbf a_3}^{\perp}|| \\
#                 \end{bmatrix}}}
#                 $
#
# where $\mathbf {a_1}$, $\mathbf {a_2}$, $\mathbf {a_3}$ are the column vectors of $\mathbf A$, $\mathbf {q_1}$, $\mathbf {q_2}$, $\mathbf {q_3}$ are the column vectors of orthogonal matrix $\mathbf Q$, and $\mathbf R$ is an upper triangular matrix.
#
# Step 1: To find $\mathbf Q$ and $\mathbf R$
#
# To calculate $\mathbf {q_1}$, we have
# $\mathbf { a_1} = \mathbf{
#             {
#             \begin{bmatrix}
#                 \rm -4 \\
#                 \rm -8 \\
#                 \rm 16 \\
#             \end{bmatrix}}}
# $
# ,
# $\begin{equation} \tag{1}
# {\implies} ||\mathbf {a_1}|| = \sqrt{-4^2 + -8^2 + 16^2} = 4\sqrt{21} = r_{11}
# \end{equation}$
#
# $$ \begin{equation} \tag{2}
# {\implies} \mathbf {q_1} = \frac{\mathbf a_1}{||{\mathbf a_1}||}  = \frac{1}{4\sqrt{21}}
#
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm -4 \\
#             \rm -8 \\
#             \rm 16 \\
#         \end{bmatrix}}}
# =
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-1}{\sqrt{21}} \\
#             \rm \frac{-2}{\sqrt{21}} \\
#             \rm \frac{4}{\sqrt{21}} \\
#         \end{bmatrix}}}
# \end{equation}$$
#
# Now to calculate $\mathbf {q_2}$, we have ${\mathbf a_2}^{\perp} = {\mathbf a_2} - ({r_{12}}){\mathbf q_1}$, where ${r_{12}} = {\mathbf a_2}^{T}{\mathbf q_1} $
#
# $$ \begin{equation} \tag{3}
# {\implies} {r_{12}} =
#
#         \mathbf{
#             {
#             \begin{bmatrix}
#                 5 & -5 & -5 \\
#             \end{bmatrix}}}
#         \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-1}{\sqrt{21}} \\
#             \rm \frac{-2}{\sqrt{21}} \\
#             \rm \frac{4}{\sqrt{21}} \\
#         \end{bmatrix}}}
#         = \frac{-15}{\sqrt{21}}
#
#     \end{equation}$$
#
# Now, ${\mathbf a_2}^{\perp} = {\mathbf a_2} - ({r_{12}}){\mathbf q_1} = $
# ${
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm 5 \\
#             \rm -5 \\
#             \rm -5 \\
#         \end{bmatrix}}}
# }
# $ - $ \frac{-15}{\sqrt{21}}
# \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-1}{\sqrt{21}} \\
#             \rm \frac{-2}{\sqrt{21}} \\
#             \rm \frac{4}{\sqrt{21}} \\
#         \end{bmatrix}}}$
#
# $$\begin{equation} \tag{4}
# {\implies} {\mathbf a_2}^{\perp} = \frac{5}{7}
#
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm 6 \\
#             \rm -9 \\
#             \rm -3 \\
#         \end{bmatrix}}}
# \end{equation}$$
#
# $$\begin{equation} \tag{5}
# {\implies} {||\mathbf a_2}^{\perp}|| = \frac{5}{7} \sqrt{6^2 + -9^2 + -3^2} = \frac{5}{7} \sqrt{126} = {r_{22}}
# \end{equation}$$
#
# $$ \begin{equation} \tag{6}
# {\implies} \mathbf {q_2} = \frac{\mathbf {a_2}^{\perp}}{||{\mathbf a_2}^{\perp}||}  = \frac{1}{\frac{5}{7} \sqrt{126}}
# \frac{5}{7}
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm 6 \\
#             \rm -9 \\
#             \rm -3 \\
#         \end{bmatrix}}}
# =
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{6}{\sqrt{126}} \\
#             \rm \frac{-9}{\sqrt{126}} \\
#             \rm \frac{-3}{\sqrt{126}} \\
#         \end{bmatrix}}}
#     \end{equation}$$
#
# Now to calculate $\mathbf {q_3}$, we have ${\mathbf a_3}^{\perp} = {\mathbf a_3} - ({r_{13}}){\mathbf q_1} - ({r_{23}}){\mathbf q_2}$, where ${r_{13}} = {\mathbf a_3}^{T}{\mathbf q_1}$ and ${r_{23}} = {\mathbf a_3}^{T}{\mathbf q_2}$
#
# $$ \begin{equation} \tag{7}
# {\implies} {r_{13}} =
#
#         \mathbf{
#             {
#             \begin{bmatrix}
#                 -5 & -3 & 6 \\
#             \end{bmatrix}}}
#         \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-1}{\sqrt{21}} \\
#             \rm \frac{-2}{\sqrt{21}} \\
#             \rm \frac{4}{\sqrt{21}} \\
#         \end{bmatrix}}}
#         = \frac{35}{\sqrt{21}}
#     \end{equation}$$
#
# $$
#     \begin{equation} \tag{8}
#     {\implies} {r_{23}} =
#
#         \mathbf{
#             {
#             \begin{bmatrix}
#                 -5 & -3 & 6 \\
#             \end{bmatrix}}}
#         \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{6}{\sqrt{126}} \\
#             \rm \frac{-9}{\sqrt{126}} \\
#             \rm \frac{-3}{\sqrt{126}} \\
#         \end{bmatrix}}}
#         = \frac{-21}{\sqrt{126}}
#     \end{equation}
# $$
#
# Now we have, ${\mathbf a_3}^{\perp} = {\mathbf a_3} - ({r_{13}}){\mathbf q_1} - ({r_{23}}){\mathbf q_2}$
# $ = $
# $\mathbf{
#         {
#         \begin{bmatrix}
#             \rm -5 \\
#             \rm -3 \\
#             \rm 6 \\
#         \end{bmatrix}}} $
# $ - $ $\frac{35}{\sqrt{21}}$
# $
# \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-1}{\sqrt{21}} \\
#             \rm \frac{-2}{\sqrt{21}} \\
#             \rm \frac{4}{\sqrt{21}} \\
#         \end{bmatrix}}}
# $
# $ - $ $\frac{-21}{\sqrt{126}}$
# $
# \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{6}{\sqrt{126}} \\
#             \rm \frac{-9}{\sqrt{126}} \\
#             \rm \frac{-3}{\sqrt{126}} \\
#         \end{bmatrix}}}
# $
#
# $$\begin{equation} \tag{9}
# {\implies} {\mathbf a_3}^{\perp} =
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-7}{3} \\
#             \rm \frac{-7}{6} \\
#             \rm \frac{-7}{6} \\
#         \end{bmatrix}}}
# \end{equation}$$
#
# $$\begin{equation} \tag{10}
# {\implies} {||\mathbf a_3}^{\perp}|| = \frac{7}{3} \sqrt{-1^2 + {(\frac{-1}{2})}^2 + {(\frac{-1}{2})}^2} = \frac{7}{\sqrt{6}} = {r_{33}}
# \end{equation}$$
#
# $$ \begin{equation} \tag{11}
# {\implies} \mathbf {q_3} = \frac{\mathbf {a_3}^{\perp}}{||{\mathbf a_3}^{\perp}||}  = \frac{1}{\frac{7}{\sqrt{6}}}
# \frac{5}{7}
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-7}{3} \\
#             \rm \frac{-7}{6} \\
#             \rm \frac{-7}{6} \\
#         \end{bmatrix}}}
# =
#     \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-\sqrt{2}}{\sqrt{3}} \\
#             \rm \frac{-1}{\sqrt{6}} \\
#             \rm \frac{-1}{\sqrt{6}} \\
#         \end{bmatrix}}}
#     \end{equation}$$
#
# Finally, plugging the values obtained in equations (1) to (11), we get:
# $$
# \mathbf{Q} = \mathbf{
#         {
#         \begin{bmatrix}
#             \rm \frac{-1}{\sqrt{21}} & \frac{6}{\sqrt{126}} & \frac{\sqrt{-2}}{\sqrt{3}} \\
#             \rm \frac{-2}{\sqrt{21}} & \frac{-9}{\sqrt{126}} & \frac{-1}{\sqrt{6}} \\
#             \rm \frac{4}{\sqrt{21}} & \frac{-3}{\sqrt{126}} & \frac{-1}{\sqrt{6}}\\
#         \end{bmatrix}}}
#         {\approx} \mathbf{
#         {
#         \begin{bmatrix}
#             \rm -0.218 & 0.534 & -0.817 \\
#             \rm -0.436 & -0.801 & -0.408 \\
#             \rm 0.873 & -0.267 & -0.408 \\
#         \end{bmatrix}}}
# $$
#
# $$
# \mathbf{R} = \mathbf{
#         {
#         \begin{bmatrix}
#             \rm 4\sqrt{21} & \frac{-15}{\sqrt{21}} & \frac{35}{\sqrt{21}} \\
#             \rm 0 & \frac{5{\sqrt{126}}}{7} & \frac{-21}{\sqrt{126}} \\
#             \rm 0 & 0 & \frac{7}{\sqrt{6}}\\
#         \end{bmatrix}}}
#         {\approx} \mathbf{
#         {
#         \begin{bmatrix}
#             \rm 18.33 & -3.27 & 7.63 \\
#             \rm 0 & 8.01 & -1.87 \\
#             \rm 0 & 0 & 2.85 \\
#         \end{bmatrix}}}
# $$
#
# Step 2: Solving $\mathbf{A}\mathbf{x}=\mathbf{b}$ by susbstituting $\mathbf{A} = \mathbf{Q}\mathbf{R}$
#
# This is equivalent to solving
#     $$
#         \mathbf{R}\mathbf{x} = \mathbf{Q^T}\mathbf{b}
#     $$
#
# $$
#     \mathbf{
#         {
#             \underbrace{
#                 \begin{bmatrix}
#                     \rm 4\sqrt{21} & \frac{-15}{\sqrt{21}} & \frac{35}{\sqrt{21}} \\
#                     \rm 0 & \frac{5{\sqrt{126}}}{7} & \frac{-21}{\sqrt{126}} \\
#                     \rm 0 & 0 & \frac{7}{\sqrt{6}}\\
#                 \end{bmatrix}}_{\mathbf{R}}}}
#
#     \mathbf{
#         {
#             \underbrace{
#                 \begin{bmatrix}
#                     \rm x_1 \\
#                     \rm x_2 \\
#                     \rm x_3 \\
#                 \end{bmatrix}}_{\mathbf{x}}}}
#
#     = \mathbf{
#         {
#             \underbrace{
#                 \begin{bmatrix}
#                 \rm \frac{-1}{\sqrt{21}} & \frac{-2}{\sqrt{21}} & \frac{4}{\sqrt{21}} \\
#                 \rm \frac{6}{\sqrt{126}} & \frac{-9}{\sqrt{126}} & \frac{-3}{\sqrt{126}} \\
#                 \rm \frac{-\sqrt{2}}{\sqrt{3}} & \frac{-1}{\sqrt{6}} & \frac{-1}{\sqrt{6}}\\
#                 \end{bmatrix}}_{\mathbf{Q^T}}}}
#
#         \mathbf{
#         {
#             \underbrace{
#                 \begin{bmatrix}
#                     \rm -29 \\
#                     \rm -15 \\
#                     \rm 45 \\
#                 \end{bmatrix}}_{\mathbf{b}}}}
#
# $$
#
# $$
#     \mathbf{
#         {
#             \begin{bmatrix}
#                 \rm 4\sqrt{21} & \frac{-15}{\sqrt{21}} & \frac{35}{\sqrt{21}} \\
#                 \rm 0 & \frac{5{\sqrt{126}}}{7} & \frac{-21}{\sqrt{126}} \\
#                 \rm 0 & 0 & \frac{7}{\sqrt{6}}\\
#             \end{bmatrix}}}
#     \mathbf{
#         {
#             \begin{bmatrix}
#                 \rm x_1 \\
#                 \rm x_2 \\
#                 \rm x_3 \\
#             \end{bmatrix}}}
#     =\mathbf{
#         {
#         \underbrace{
#             \begin{bmatrix}
#                 \rm \frac{239}{\sqrt{21}} \\
#                 \rm \frac{-174}{\sqrt{126}} \\
#                 \rm \frac{28}{\sqrt{6}} \\
#             \end{bmatrix}}_{\mathbf{Q^T b}}}}
# $$
#
# Using Backwards Substitution, we have,
#
# $$
#         \begin{cases}
#             \frac{7}{\sqrt{6}}x_3 = \frac{28}{\sqrt{6}} \\
#             \frac{5\sqrt{126}}{7}x_2 - \frac{21}{\sqrt{126}}x_3 = \frac{-174}{\sqrt{126}} \\
#             {4\sqrt{21}}x_1 + \frac{-15}{\sqrt{21}}x_2 + \frac{35}{\sqrt{21}}x_3 = \frac{239}{\sqrt{21}}
#         \end{cases}\ \rightarrow
#         \begin{cases}
#             x_3 = 4 \\
#             x_2 = -1 \\
#             x_1 = 1
#         \end{cases}
# $$
